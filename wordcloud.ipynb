# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwon0915/datacreatecamp/blob/main/wordcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/jiwon0915/datacreatecamp.git
import numpy as np
import pandas as pd
# Out:
# Cloning into 'datacreatecamp'...
# ...

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
data=pd.read_csv("/gdrive/My Drive/sentiment_dtm_train.csv",encoding="CP949")
del data['Id']

# %%
mask1 = (data.label == 1)
pos = data.loc[mask1,:].sum(axis=0)
del pos['label']
pos_dict = pos.to_dict()

mask2 = (data.label == 0)
neg = data.loc[mask2,:].sum(axis=0)
del neg['label']
neg_dict = neg.to_dict()

# %%
neg_dict
# Out:
# {'가게': 52,
#  '가격': 21,
#  '가격대비': 43,
#  '가격도': 44,
#  '가격에': 18,
#  '가격은': 41,
#  '가격이': 34,
#  '가고': 38,
#  '가끔': 14,
#  '가면': 22,
#  '가봤는데': 15,
#  '가서': 77,
#  '가장': 15,
#  '가지마세요': 55,
#  '갈때마다': 25,
#  '감사합니다': 10,
#  '갑니다': 15,
#  '갔는데': 130,
#  '갔다가': 48,
#  '갔었는데': 22,
#  '강추': 13,
#  '같네요': 34,
#  '같습니다': 19,
#  '같아요': 37,
#  '같은': 46,
#  '같이': 38,
#  '개인적으로': 17,
#  '걍': 44,
#  '거의': 50,
#  '것': 57,
#  '계속': 76,
#  '고기': 53,
#  '고기가': 29,
#  '고기도': 20,
#  '곳': 44,
#  '굉장히': 18,
#  '국물이': 11,
#  '굿': 11,
#  '그': 101,
#  '그냥': 335,
#  '그래도': 51,
#  '그래서': 69,
#  '그런': 40,
#  '그런데': 26,
#  '그런지': 29,
#  '그럼': 47,
#  '그렇게': 92,
#  '그리고': 141,
#  '근데': 71,
#  '글': 35,
#  '기분': 110,
#  '기분이': 46,
#  '기분좋게': 24,
#  '깔끔하고': 14,
#  '깨끗하고': 5,
#  '꼭': 50,
#  '나오고': 35,
#  '나오는': 29,
#  '나와서': 26,
#  '난': 16,
#  '내': 37,
#  '내가': 86,
#  '너무': 376,
#  '너무너무': 8,
#  '넘': 43,
#  '다': 288,
#  '다들': 29,
#  '다른': 152,
#  '다시': 148,
#  '다시는': 135,
#  '다신': 147,
#  '다음에': 27,
#  '대박': 20,
# ...

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = '/gdrive/My Drive/Typo_DabangguB.ttf', 
                      background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(pos_dict)

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
wordcloud = WordCloud(font_path = '/gdrive/My Drive/Typo_DabangguB.ttf', 
                      background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(neg_dict)

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
pos2 = pos.drop(['정말','진짜'])
pos2_dict = pos2.to_dict()

neg2 = neg.drop(['정말','진짜'])
neg2_dict = neg2.to_dict()

# %%
wordcloud = WordCloud(font_path = '/gdrive/My Drive/Typo_DabangguB.ttf', 
                      background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(pos2_dict)

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
wordcloud = WordCloud(font_path = '/gdrive/My Drive/Typo_DabangguB.ttf', 
                      background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(neg2_dict)

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
